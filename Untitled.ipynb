# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("https://raw.githubusercontent.com/ektanegi25/Water-Sensor-repository/main/wafer_23012020_041211.csv")
df.head()
# Out:
#   Unnamed: 0  Sensor-1  Sensor-2   Sensor-3   Sensor-4  Sensor-5  Sensor-6  \
# 0  Wafer-801   2968.33   2476.58  2216.7333  1748.0885    1.1127     100.0
# 1  Wafer-802   2961.04   2506.43  2170.0666  1364.5157    1.5447     100.0
# 2  Wafer-803   3072.03   2500.68  2205.7445  1363.1048    1.0518     100.0
# 3  Wafer-804   3021.83   2419.83  2205.7445  1363.1048    1.0518     100.0
# 4  Wafer-805   3006.95   2435.34  2189.8111  1084.6502    1.1993     100.0
#
#    Sensor-7  Sensor-8  Sensor-9  ...  Sensor-582  Sensor-583  Sensor-584  \
# 0   97.5822    0.1242    1.5300  ...         NaN      0.5004      0.0120
# 1   96.7700    0.1230    1.3953  ...         NaN      0.4994      0.0115
# 2  101.8644    0.1220    1.3896  ...         NaN      0.4987      0.0118
# 3  101.8644    0.1220    1.4108  ...         NaN      0.4934      0.0123
# 4  104.8856    0.1234    1.5094  ...         NaN      0.4987      0.0145
#
# ...

# %%
#df.to_csv('Water_sensor_data')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Columns: 592 entries, Unnamed: 0 to Good/Bad
# dtypes: float64(494), int64(97), object(1)
# memory usage: 462.6+ KB

# %%
df.tail()
# Out:
#    Unnamed: 0  Sensor-1  Sensor-2   Sensor-3   Sensor-4  Sensor-5  Sensor-6  \
# 95  Wafer-896   3013.66   2526.44  2185.2111  1141.6306    0.8447     100.0
# 96  Wafer-897   2982.87   2477.01  2315.2667  2360.1325    1.1259     100.0
# 97  Wafer-898   3084.82   2387.42  2171.5000  1028.4440    0.7899     100.0
# 98  Wafer-899   2955.87   2541.89        NaN        NaN       NaN       NaN
# 99  Wafer-900   2914.86   2465.11  2210.2778  2120.5760    1.0700     100.0
#
#     Sensor-7  Sensor-8  Sensor-9  ...  Sensor-582  Sensor-583  Sensor-584  \
# 95  100.5978    0.1217    1.5337  ...         NaN      0.5013      0.0076
# 96   90.1144    0.1160    1.4695  ...         NaN      0.5003      0.0106
# 97  101.5122    0.1224    1.3603  ...         NaN      0.5016      0.0130
# 98       NaN       NaN    1.4493  ...         NaN      0.5023      0.0140
# 99   95.1089    0.1230    1.5817  ...         NaN      0.5026      0.0121
#
# ...

# %%
df.rename(columns={'Unnamed: 0':'Wafers'},inplace =True)

# %%
df.head()
# Out:
#       Wafers  Sensor-1  Sensor-2   Sensor-3   Sensor-4  Sensor-5  Sensor-6  \
# 0  Wafer-801   2968.33   2476.58  2216.7333  1748.0885    1.1127     100.0
# 1  Wafer-802   2961.04   2506.43  2170.0666  1364.5157    1.5447     100.0
# 2  Wafer-803   3072.03   2500.68  2205.7445  1363.1048    1.0518     100.0
# 3  Wafer-804   3021.83   2419.83  2205.7445  1363.1048    1.0518     100.0
# 4  Wafer-805   3006.95   2435.34  2189.8111  1084.6502    1.1993     100.0
#
#    Sensor-7  Sensor-8  Sensor-9  ...  Sensor-582  Sensor-583  Sensor-584  \
# 0   97.5822    0.1242    1.5300  ...         NaN      0.5004      0.0120
# 1   96.7700    0.1230    1.3953  ...         NaN      0.4994      0.0115
# 2  101.8644    0.1220    1.3896  ...         NaN      0.4987      0.0118
# 3  101.8644    0.1220    1.4108  ...         NaN      0.4934      0.0123
# 4  104.8856    0.1234    1.5094  ...         NaN      0.4987      0.0145
#
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
df_train, df_test= train_test_split(df, test_size=0.2, random_state=42)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 80 entries, 55 to 51
# Columns: 592 entries, Wafers to Good/Bad
# dtypes: float64(494), int64(97), object(1)
# memory usage: 370.6+ KB

# %%
df_train.describe().T
# Out:
#             count         mean         std        min          25%  \
# Sensor-1     79.0  3019.048228   72.665372  2889.6700  2975.425000
# Sensor-2     80.0  2494.058875   68.166898  2254.9900  2452.517500
# Sensor-3     78.0  2202.758988   31.633772  2114.6667  2189.966700
# Sensor-4     78.0  1519.467071  471.962104   978.7832  1111.543600
# Sensor-5     78.0     1.201382    0.365870     0.7531     0.850075
# ...           ...          ...         ...        ...          ...
# Sensor-587   80.0     0.023543    0.011668     0.0099     0.013850
# Sensor-588   80.0     0.014155    0.007263     0.0048     0.009000
# Sensor-589   80.0     0.004439    0.002324     0.0017     0.002650
# Sensor-590   80.0    72.116730   50.770394    20.3091    33.654025
# Good/Bad     80.0    -0.850000    0.530106    -1.0000    -1.000000
#
#                    50%          75%        max
# Sensor-1    3004.39000  3065.730000  3221.2100
# Sensor-2    2502.44500  2532.755000  2664.5200
# ...

# %%
df_train['Good/Bad'].isnull().sum()
# Out:
# 0

# %%
df_train.isnull().sum().sum()
# Out:
# 1822

# %%
##calculate the missing value percentage in train daata

df_train.isnull().sum().sum()/(df_train.shape[0] *(df_train.shape[1] -1))*100
# Out:
# 3.8536379018612523

# %%
### Approx 4 percent data is missing

# %%
##calculate the missing value percentage in test data

df_test.isnull().sum().sum()/(df_test.shape[0] *(df_test.shape[1] -1))*100
# Out:
# 4.094754653130288

# %%
# Approx 4 percent data is missing in TEst dataset .

# %%
plt.figure( figsize=(15,100))
for i, col in enumerate(df_train.columns[1:51]):
    plt.subplot(60,3,i+1)
    sns.histplot(x=df_train[col])
    plt.xlabel(col, weight='bold')
    plt.tight_layout()

# %%
rand_50_sensors=[]

for i in range(50):
    if i not in rand_50_sensors:
        rand_50_sensors.append(np.random.randint(1,591))

# %%
plt.figure( figsize=(15,100))
for i, col in enumerate(df_train.columns[rand_50_sensors]):
    plt.subplot(60,3,i+1)
    sns.histplot(x=df_train[col])
    plt.xlabel(col, weight='bold')
    plt.tight_layout()

# %%
# funxtion to frop the feature which have zero std, which have zero variability,

# %%
def get_cols_zero_std(df :pd.DataFrame):
    cols_to_drop=[]
    num_col=[i for i in df.columns if df[i].dtype !='O']
    for i in num_col:
        if df[i].std()==0:
            cols_to_drop.append(i)
    return cols_to_drop

# %%
def get_reduntant_col(df:pd.DataFrame,missing_thresh=0.7):
    cols_missing_ratio=df.isnull().sum().div(df.shape[0])
    cols_to_drop= list(cols_missing_ratio[cols_missing_ratio>missing_thresh].index)
    return cols_to_drop

# %%
cols_drop_1=get_cols_zero_std(df=df_train)

# %%
cols_drop_1
# Out:
# ['Sensor-6',
#  'Sensor-14',
#  'Sensor-43',
#  'Sensor-50',
#  'Sensor-53',
#  'Sensor-70',
#  'Sensor-75',
#  'Sensor-98',
#  'Sensor-142',
#  'Sensor-150',
#  'Sensor-179',
#  'Sensor-180',
#  'Sensor-187',
#  'Sensor-190',
#  'Sensor-191',
#  'Sensor-192',
#  'Sensor-193',
#  'Sensor-194',
#  'Sensor-195',
#  'Sensor-207',
#  'Sensor-210',
#  'Sensor-227',
#  'Sensor-230',
#  'Sensor-231',
#  'Sensor-232',
#  'Sensor-233',
#  'Sensor-234',
#  'Sensor-235',
#  'Sensor-236',
#  'Sensor-237',
#  'Sensor-238',
#  'Sensor-241',
#  'Sensor-242',
#  'Sensor-243',
#  'Sensor-244',
#  'Sensor-257',
#  'Sensor-258',
#  'Sensor-259',
#  'Sensor-260',
#  'Sensor-261',
#  'Sensor-262',
#  'Sensor-263',
#  'Sensor-264',
#  'Sensor-265',
#  'Sensor-266',
#  'Sensor-267',
#  'Sensor-277',
#  'Sensor-285',
#  'Sensor-314',
#  'Sensor-315',
#  'Sensor-316',
#  'Sensor-323',
#  'Sensor-326',
#  'Sensor-327',
#  'Sensor-328',
#  'Sensor-329',
#  'Sensor-330',
#  'Sensor-331',
#  'Sensor-343',
# ...

# %%
cols_drop_2=get_reduntant_col(df=df_train,missing_thresh=0.7)

# %%
len(cols_drop_2)
# Out:
# 4

# %%
cols_to_drop=cols_drop_1+cols_drop_2+['Wafers']

# %%
len(cols_to_drop)
# Out:
# 127

# %%
X, y=df_train.drop(cols_to_drop, axis=1), df_train['Good/Bad']

# %%
X.shape
# Out:
# (80, 465)

# %%
y.shape
# Out:
# (80,)

# %%
y.value_counts()
# Out:
# -1    74
#  1     6
# Name: Good/Bad, dtype: int64

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import KNNImputer, SimpleImputer
from sklearn.preprocessing import RobustScaler

# %%
imputer = KNNImputer(n_neighbors=3)
pre_process=Pipeline(steps =[ ('Imputer', imputer), ('Scaling',RobustScaler())])
pre_process
# Out:
# Pipeline(steps=[('Imputer', KNNImputer(n_neighbors=3)),
#                 ('Scaling', RobustScaler())])

# %%
X_trans=pre_process.fit_transform(X)
X_trans.shape
# Out:
# (80, 465)
